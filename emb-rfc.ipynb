# %%
# !pip install hazm
# !pip install transformers

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import hazm
import re

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import BertTokenizer

# %%
data = pd.read_csv('/kaggle/input/snappfood-persian-sentiment-analysis/Snappfood - Sentiment Analysis.csv', on_bad_lines='skip' , delimiter='\t')
data = data[['comment', 'label_id']]
data.head()
# Out:
#                                              comment  label_id
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح       1.0
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...       0.0
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...       1.0
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...       0.0
# 4                      شیرینی وانیلی فقط یک مدل بود.       0.0

# %%
data.dropna(inplace=True)
data = data.drop_duplicates(subset=['comment'], keep='first')
data = data.reset_index(drop=True)
data['label_id'] = data['label_id'].astype(int)
labels = ['HAPPY', 'SAD']
data['comment_len_by_words'] = data['comment'].apply(lambda t: len(hazm.word_tokenize(t)))

data.head(20)
# Out:
#                                               comment  label_id  \
# 0     واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح         1
# 1   قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...         0
# 2   قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...         1
# 3   عالللی بود همه چه درست و به اندازه و کیفیت خوب...         0
# 4                       شیرینی وانیلی فقط یک مدل بود.         0
# 5              بدترین پیتزایی که تا به حال خورده بودم         1
# 6                             از همه لحاظ عالی ممنونم         0
# 7   کیفیت غذا متوسط رو به پایین بود انگار داخل یه ...         1
# 8   همه اقلام تازه و به روز وخیلیییییی سریع بدستم ...         0
# 9   همه چی خوب ولی هات داگ دورش کلا سوخته بود و دا...         1
# 10  اکلر فوق العاده بود اما بافت چیزکیک مونده بود ...         0
# 11    خوب بود و از رستوران غنچه و اسنپ فود تشکر میکنم         0
# 12  مثل همیشه عااااالی هستی پرپروک جاااااان مچکریم...         0
# 13                       Kheili khub bud mersi vaghan         0
# 14  عکس با شیریبی که ارسال کردند فرق داشت و خیلی ن...         1
# 15              سریع سفارش بدستم رسید ممنونم اسنپ فود         0
# 16              خیلی عالی بود خیلی هم زود رسید خوشمزه         0
# 17                  هات داگ یکم خام بود. حجمش خوب بود         0
# 18   ممنون که به صلاحدید هودتون سفارش رو تغییر دادید.         1
# 19  پیتزا سرد و خیلی خیلی بدمزه بود و میگوتون افتض...         1
#
#     comment_len_by_words
# 0                      9
# 1                     28
# 2                     19
# 3                     21
# 4                      7
# 5                      7
# 6                      5
# 7                     25
# 8                     12
# 9                     14
# 10                    12
# 11                    11
# 12                     8
# 13                     5
# 14                    18
# 15                     7
# 16                     8
# 17                     9
# 18                    10
# 19                    32

# %%
minlim, maxlim = 3, 62

data['comment_len_by_words'] = data['comment_len_by_words'].apply(lambda len_t: len_t if minlim < len_t <= maxlim else None)
data = data.dropna(subset=['comment_len_by_words'])
data = data.reset_index(drop=True)

# %%
fig = go.Figure()

fig.add_trace(go.Histogram(
    x=data['comment_len_by_words']
))

fig.update_layout(
    title_text='Distribution of word counts within comments',
    xaxis_title_text='Word Count',
    yaxis_title_text='Frequency',
    bargap=0.2,
    bargroupgap=0.2)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d70a4433-bc8d-43d3-97d3-044dcbd542fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d70a4433-bc8d-43d3-97d3-044dcbd542fa")) {                    Plotly.newPlot(                        "d70a4433-bc8d-43d3-97d3-044dcbd542fa",                        [{"x":[9.0,28.0,19.0,21.0,7.0,7.0,5.0,25.0,12.0,14.0,12.0,11.0,8.0,5.0,18.0,7.0,8.0,9.0,10.0,32.0,44.0,12.0,12.0,13.0,12.0,8.0,12.0,13.0,11.0,12.0,6.0,13.0,20.0,5.0,32.0,20.0,11.0,15.0,21.0,6.0,15.0,17.0,5.0,5.0,44.0,12.0,4.0,16.0,4.0,21.0,21.0,15.0,12.0,58.0,9.0,32.0,8.0,16.0,11.0,13.0,19.0,7.0,7.0,11.0,21.0,15.0,16.0,18.0,30.0,10.0,6.0,23.0,5.0,22.0,7.0,13.0,8.0,11.0,5.0,20.0,31.0,9.0,5.0,9.0,41.0,29.0,11.0,16.0,20.0,16.0,10.0,18.0,23.0,15.0,7.0,28.0,5.0,4.0,10.0,29.0,5.0,12.0,8.0,4.0,14.0,7.0,13.0,12.0,37.0,36.0,20.0,16.0,42.0,55.0,17.0,5.0,23.0,6.0,16.0,14.0,11.0,15.0,14.0,9.0,6.0,10.0,9.0,11.0,9.0,13.0,4.0,16.0,21.0,9.0,11.0,9.0,18.0,21.0,17.0,5.0,8.0,19.0,9.0,4.0,7.0,6.0,9.0,4.0,26.0,26.0,9.0,8.0,14.0,12.0,5.0,31.0,8.0,16.0,11.0,5.0,10.0,5.0,4.0,8.0,49.0,7.0,8.0,18.0,34.0,32.0,7.0,21.0,31.0,54.0,11.0,17.0,19.0,18.0,13.0,5.0,8.0,7.0,13.0,13.0,24.0,14.0,17.0,7.0,48.0,23.0,24.0,23.0,14.0,20.0,18.0,17.0,28.0,15.0,9.0,5.0,17.0,7.0,6.0,11.0,39.0,7.0,28.0,8.0,11.0,5.0,32.0,16.0,14.0,10.0,18.0,9.0,20.0,6.0,24.0,6.0,14.0,25.0,60.0,17.0,58.0,10.0,20.0,5.0,15.0,25.0,12.0,9.0,32.0,28.0,8.0,19.0,9.0,6.0,5.0,7.0,28.0,20.0,8.0,17.0,9.0,25.0,6.0,34.0,53.0,27.0,7.0,19.0,9.0,11.0,12.0,5.0,9.0,7.0,19.0,36.0,5.0,17.0,12.0,25.0,4.0,12.0,26.0,6.0,7.0,16.0,9.0,47.0,20.0,7.0,22.0,20.0,8.0,14.0,22.0,16.0,8.0,22.0,11.0,29.0,21.0,8.0,47.0,18.0,34.0,9.0,19.0,16.0,7.0,24.0,10.0,13.0,22.0,9.0,8.0,10.0,10.0,6.0,26.0,5.0,14.0,21.0,57.0,12.0,19.0,15.0,15.0,14.0,20.0,60.0,7.0,13.0,5.0,10.0,16.0,6.0,4.0,13.0,8.0,9.0,11.0,42.0,29.0,22.0,4.0,15.0,9.0,7.0,7.0,50.0,5.0,11.0,16.0,11.0,52.0,21.0,16.0,31.0,20.0,43.0,15.0,5.0,11.0,12.0,12.0,4.0,8.0,7.0,18.0,33.0,7.0,14.0,12.0,53.0,54.0,15.0,5.0,27.0,11.0,13.0,7.0,11.0,30.0,20.0,6.0,12.0,19.0,16.0,8.0,33.0,29.0,13.0,10.0,13.0,59.0,37.0,12.0,28.0,11.0,16.0,7.0,10.0,47.0,6.0,47.0,10.0,9.0,28.0,24.0,17.0,17.0,12.0,13.0,52.0,13.0,32.0,11.0,9.0,6.0,26.0,8.0,12.0,7.0,22.0,19.0,34.0,10.0,16.0,7.0,7.0,19.0,8.0,17.0,22.0,41.0,28.0,10.0,18.0,5.0,18.0,21.0,9.0,13.0,12.0,20.0,14.0,10.0,6.0,6.0,13.0,14.0,11.0,9.0,6.0,14.0,14.0,18.0,21.0,10.0,21.0,18.0,34.0,18.0,5.0,4.0,22.0,8.0,7.0,10.0,19.0,6.0,7.0,23.0,10.0,7.0,20.0,4.0,18.0,29.0,6.0,10.0,16.0,26.0,13.0,4.0,10.0,5.0,25.0,30.0,11.0,11.0,10.0,31.0,8.0,12.0,38.0,18.0,19.0,26.0,13.0,20.0,6.0,27.0,10.0,6.0,51.0,22.0,11.0,11.0,45.0,18.0,5.0,30.0,5.0,7.0,14.0,20.0,32.0,36.0,10.0,15.0,20.0,5.0,26.0,16.0,12.0,11.0,38.0,23.0,22.0,27.0,20.0,24.0,26.0,8.0,27.0,7.0,8.0,26.0,17.0,11.0,18.0,6.0,24.0,16.0,48.0,21.0,25.0,16.0,10.0,13.0,48.0,23.0,30.0,10.0,27.0,20.0,10.0,7.0,11.0,8.0,7.0,25.0,18.0,59.0,12.0,10.0,14.0,10.0,19.0,14.0,28.0,14.0,25.0,24.0,14.0,8.0,9.0,12.0,34.0,15.0,6.0,11.0,6.0,7.0,15.0,7.0,26.0,11.0,40.0,18.0,29.0,7.0,6.0,50.0,24.0,15.0,4.0,30.0,9.0,15.0,7.0,8.0,31.0,6.0,18.0,17.0,21.0,24.0,13.0,14.0,34.0,9.0,7.0,12.0,4.0,10.0,15.0,20.0,6.0,26.0,11.0,11.0,22.0,7.0,32.0,9.0,11.0,6.0,28.0,6.0,13.0,10.0,8.0,17.0,9.0,13.0,54.0,7.0,43.0,10.0,23.0,18.0,11.0,45.0,51.0,10.0,45.0,7.0,30.0,44.0,15.0,24.0,18.0,20.0,10.0,13.0,20.0,7.0,12.0,34.0,54.0,7.0,4.0,16.0,19.0,35.0,35.0,12.0,17.0,11.0,9.0,18.0,10.0,20.0,28.0,20.0,9.0,29.0,22.0,28.0,11.0,10.0,9.0,10.0,15.0,20.0,21.0,17.0,38.0,4.0,6.0,8.0,21.0,27.0,56.0,13.0,30.0,10.0,7.0,13.0,8.0,8.0,5.0,10.0,16.0,8.0,17.0,7.0,5.0,9.0,4.0,41.0,27.0,9.0,17.0,12.0,10.0,27.0,22.0,18.0,12.0,16.0,25.0,32.0,5.0,16.0,20.0,44.0,12.0,27.0,20.0,35.0,36.0,44.0,7.0,34.0,5.0,25.0,7.0,5.0,12.0,9.0,18.0,28.0,33.0,9.0,9.0,8.0,23.0,12.0,16.0,34.0, ...

# %%
data['comment'] = data['comment'].apply(lambda x: re.sub(r'[\da-zA-Z\!\(\)\-\[\]\{\}\;\:\'\"\\\,\<\>\.\/\?\@\#\$\%\^\&\*\_\~\؟\،\٪\×\÷\»\«]', '', x))
normalizer = hazm.Normalizer()
data['comment'] = data['comment'].apply(lambda x: normalizer.normalize(x.strip()))
data['cleaned_comment_len_by_words'] = data['comment'].apply(lambda t: len(hazm.word_tokenize(t)))
data['cleaned_comment_len_by_words'] = data['cleaned_comment_len_by_words'].apply(lambda len_t: len_t if minlim < len_t <= maxlim else None)
data = data.dropna(subset=['cleaned_comment_len_by_words'])
data = data.reset_index(drop=True)

data.head(20)
# Out:
#                                               comment  label_id  \
# 0     واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح         1
# 1   قرار بود ساعته برسه ولی نیم ساعت زودتر از موقع...         0
# 2   قیمت این مدل اصلا با کیفیتش سازگاری نداره فقط ...         1
# 3   عالی بود همه چه درست و به اندازه و کیفیت خوب ا...         0
# 4                        شیرینی وانیلی فقط یک مدل بود         0
# 5              بدترین پیتزایی که تا به حال خورده بودم         1
# 6                             از همه لحاظ عالی ممنونم         0
# 7   کیفیت غذا متوسط رو به پایین بود انگار داخل یه ...         1
# 8   همه اقلام تازه و به‌روز وخیلیی سریع بدستم رسید...         0
# 9   همه چی خوب ولی هات داگ دورش کلا سوخته بود و دا...         1
# 10  اکلر فوق‌العاده بود اما بافت چیزکیک مونده بود ...         0
# 11   خوب بود و از رستوران غنچه و اسنپ فود تشکر می‌کنم         0
# 12          مثل همیشه عالی هستی پرپروک جان مچکریم ازت         0
# 13  عکس با شیریبی که ارسال کردند فرق داشت و خیلی ن...         1
# 14              سریع سفارش بدستم رسید ممنونم اسنپ فود         0
# 15              خیلی عالی بود خیلی هم زود رسید خوشمزه         0
# 16                   هات داگ یکم خام بود حجمش خوب بود         0
# 17    ممنون که به صلاحدید هودتون سفارش رو تغییر دادید         1
# 18  پیتزا سرد و خیلی خیلی بدمزه بود و میگوتون افتض...         1
# 19  خیلی مسخرس یک ساعت باید منتظر موند و تازه هزار...         1
#
#     comment_len_by_words  cleaned_comment_len_by_words
# 0                    9.0                           9.0
# 1                   28.0                          25.0
# 2                   19.0                          17.0
# 3                   21.0                          20.0
# 4                    7.0                           6.0
# 5                    7.0                           7.0
# 6                    5.0                           5.0
# 7                   25.0                          22.0
# 8                   12.0                          11.0
# 9                   14.0                          13.0
# 10                  12.0                          10.0
# 11                  11.0                          11.0
# 12                   8.0                           8.0
# 13                  18.0                          17.0
# 14                   7.0                           7.0
# 15                   8.0                           8.0
# 16                   9.0                           8.0
# 17                  10.0                           9.0
# 18                  32.0                          30.0
# 19                  44.0                          43.0

# %%
data = data[['comment', 'label_id']]

# %%
MODEL_PATH = 'HooshvareLab/bert-fa-base-uncased'
tokenizer = BertTokenizer.from_pretrained(MODEL_PATH)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/1.20M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/440 [00:00<?, ?B/s]

# %%
input_ids = []
attention_masks = []
for comment in data['comment']:
    encoding = tokenizer.encode_plus(
        comment,
        max_length=64,
        truncation=True,
        add_special_tokens=True,
        return_token_type_ids=True,
        return_attention_mask=True,
        padding='max_length',
    )

    input_ids.append(encoding.get("input_ids"))
    attention_masks.append(encoding.get('attention_mask'))

# %%
embedding = np.multiply(input_ids, attention_masks, dtype=float)
embedding[:3]
# Out:
# array([[2.0000e+00, 5.6680e+03, 2.3317e+04, 4.2440e+03, 2.8000e+03,
#         2.6283e+04, 4.8750e+03, 8.1130e+03, 4.9570e+03, 2.8710e+03,
#         3.3691e+04, 4.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#        [2.0000e+00, 2.9590e+03, 2.8340e+03, 1.2781e+04, 4.3170e+04,
#         3.3620e+03, 3.9730e+03, 3.5510e+03, 8.3530e+03, 2.7910e+03,
#         6.9050e+03, 3.3490e+03, 3.1240e+03, 4.9990e+03, 6.6140e+03,
#         1.1085e+04, 7.4292e+04, 7.0662e+04, 2.8420e+03, 1.4140e+04,
#         6.4280e+03, 1.0652e+04, 2.0150e+03, 1.3790e+03, 1.4140e+04,
#         1.3929e+04, 8.8480e+03, 3.0830e+03, 4.6580e+03, 1.0652e+04,
#         4.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#        [2.0000e+00, 3.3770e+03, 2.8020e+03, 3.9450e+03, 5.8990e+03,
#         2.7990e+03, 7.3833e+04, 1.0875e+04, 2.0516e+04, 3.7650e+03,
#         5.2950e+03, 2.8057e+04, 1.1231e+04, 1.2668e+04, 1.9791e+04,
#         3.4427e+04, 1.3790e+03, 1.0179e+04, 4.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]])

# %%
x_train, x_test, y_train, y_test = train_test_split(embedding, data['label_id'], test_size=0.2)

# %%
rfc = RandomForestClassifier(criterion='entropy')

rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)
print(classification_report(y_test, y_pred, target_names=['HAPPY', 'SAD']))
# Out:
#               precision    recall  f1-score   support
#
#        HAPPY       0.71      0.62      0.66      6771
#          SAD       0.65      0.74      0.69      6606
#
#     accuracy                           0.68     13377
#    macro avg       0.68      0.68      0.68     13377
# weighted avg       0.68      0.68      0.68     13377
